# %%
import pandas as pd

try:
    airports_df = pd.read_csv('/content/canadian_airports.csv')

    CANADIAN_AIRPORTS = airports_df['code'].tolist()

    print("Canadian airport codes loaded successfully:", CANADIAN_AIRPORTS)

except FileNotFoundError:
    print("Error: canadian_airports.csv not found. Please make sure the file is in the correct location.")
except KeyError:
    print("Error: 'code' column not found in the CSV file.")
# Out:
# Canadian airport codes loaded successfully: ['YYZ', 'YVR', 'YUL', 'YYC', 'YEG', 'YOW', 'YWG', 'YHZ', 'YQB', 'YXE', 'YLW', 'YYJ', 'YQR', 'YYT', 'YQT', 'YXU', 'YYG', 'YQM', 'YXY', 'YMM', 'YKA', 'YFC', 'YZF', 'YXS', 'YDF', 'YFB', 'YQU', 'YZP', 'YVM', 'YAX']

# %%
DEP_ARR_PAIRS = []

for dep in CANADIAN_AIRPORTS:
    for arr in CANADIAN_AIRPORTS:
        if dep != arr:
            if [dep, arr] not in DEP_ARR_PAIRS:
                DEP_ARR_PAIRS.append([dep, arr])

print('Number of unique departure (dep) and arrival (arr) pairs:', len(DEP_ARR_PAIRS))
# Out:
# Number of unique departure (dep) and arrival (arr) pairs: 870

# %%
print("Calculating outgoing connection for each pair:")
temp = ""
for pair in DEP_ARR_PAIRS:
  if len(temp) == 0:
    temp = pair[0]
    count = 0
  if pair[0] == temp:
    count += 1
  else:
    print(temp, count)
    temp = pair[0]
    count = 1
print(temp, count)
# Out:
# Calculating outgoing connection for each pair:
# YYZ 29
# YVR 29
# YUL 29
# YYC 29
# YEG 29
# YOW 29
# YWG 29
# YHZ 29
# YQB 29
# YXE 29
# YLW 29
# YYJ 29
# YQR 29
# YYT 29
# YQT 29
# YXU 29
# YYG 29
# YQM 29
# YXY 29
# YMM 29
# YKA 29
# YFC 29
# YZF 29
# YXS 29
# YDF 29
# YFB 29
# YQU 29
# YZP 29
# YVM 29
# YAX 29

# %%
import requests
import time
import csv
import os

def get_api_key(number_of_use):
  try:
    with open('api_keys.txt', 'r') as file:
      lines = file.readlines()
      return lines[int(number_of_use/100)].strip()
  except FileNotFoundError:
    print("Error: api_keys.txt not found. Please make sure the file is in the correct location.")
    return None
  except IndexError:
    print("Error: Not enough API keys in the api_keys.txt file for the number of requests made.")
    return None


def get_flights_between_airports(origin, destination, num_of_flights, mock=False):
  if mock:
    return ["mocked"]

  api_key = get_api_key(num_of_flights)
  if not api_key:
    return [] # Return empty list if API key is not available

  url = "http://api.aviationstack.com/v1/flights"
  params = {
    "access_key": api_key,
    "dep_iata": origin,
    "arr_iata": destination
  }

  try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    data = response.json()
    return data.get("data", [])
  except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
    return []


def log_flight(departure, arrivals, num_of_flights):
  local_log_path = 'flights_found_dep_arr_log.csv'
  drive_log_path = '/content/drive/MyDrive/flights_found_dep_arr_log.csv'
  header = ['dep', 'arr', 'number_of_flights']

  # Log to local file
  if not os.path.exists(local_log_path):
      with open(local_log_path, 'w', newline='') as file:
          writer = csv.writer(file)
          writer.writerow(header)
  with open(local_log_path, 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow([departure, arrivals, num_of_flights])

  # Log to Google Drive
  if not os.path.exists(drive_log_path):
      with open(drive_log_path, 'w', newline='') as file:
          writer = csv.writer(file)
          writer.writerow(header)
  with open(drive_log_path, 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow([departure, arrivals, num_of_flights])


def find_all_canadian_flights():
  all_flights = []
  found_flights_df = pd.DataFrame(columns=['airport1', 'airport2'])
  processed_pairs = set()

  # Read existing log to resume from where it left off
  log_path = 'flights_found_dep_arr_log.csv'
  if os.path.exists(log_path):
    with open(log_path, 'r') as file:
      reader = csv.reader(file)
      # Skip header row if it exists
      try:
          header = next(reader)
          if header != ['dep', 'arr', 'number_of_flights']:
              file.seek(0)
      except StopIteration:
          pass

      for row in reader:
        if row:
          processed_pairs.add(tuple(row[:2]))

  num_of_requests = 0
  for [dep, arr] in DEP_ARR_PAIRS:
    if (dep, arr) in processed_pairs:
      print(f"Skipping {dep} to {arr} as it's already processed.")
      continue

    print(f"[{DEP_ARR_PAIRS.index([dep,arr])}/{len(DEP_ARR_PAIRS)}] Searching for flights from {dep} to {arr}...")
    flights = get_flights_between_airports(dep, arr, num_of_requests)
    num_of_requests = num_of_requests + 1

    if flights:
      print(f"Found {len(flights)} flights from {dep} to {arr}.")
      # Logging to ensure no data is lost
      log_flight(dep, arr, len(flights))
      all_flights.extend(flights)
      found_flights_df = pd.concat([found_flights_df, pd.DataFrame({'airport1': [dep], 'airport2': [arr]})], ignore_index=True)
    else:
      print(f"No flights found from {dep} to {arr}.") # Corrected print statement

    # Sleep to respect API rate limits (essential for free tier)
    # This will take a very long time with the full list of airports.
    # Consider reducing the number of airports or increasing the sleep time if hitting rate limits.
    # time.sleep(10)  # Adjust this based on the API's rate limits


if __name__ == "__main__":
    found_flights = find_all_canadian_flights()

    if found_flights:
        print("\n--- All Found Flights ---")
        for flight in found_flights:
            flight_number = flight.get("flight", {}).get("iata")
            departure_airport = flight.get("departure", {}).get("airport")
            arrival_airport = flight.get("arrival", {}).get("airport")
            status = flight.get("flight_status")

            print(f"Flight {flight_number}: {departure_airport} -> {arrival_airport} ({status})")
    else:
        print("No flights were found during the search.")
# Out:
# [0/870] Searching for flights from YYZ to YVR...
# Found 33 flights from YYZ to YVR.
# [1/870] Searching for flights from YYZ to YUL...
# Found 55 flights from YYZ to YUL.
# [2/870] Searching for flights from YYZ to YYC...
# Found 74 flights from YYZ to YYC.
# [3/870] Searching for flights from YYZ to YEG...
# Found 24 flights from YYZ to YEG.
# [4/870] Searching for flights from YYZ to YOW...
# Found 29 flights from YYZ to YOW.
# [5/870] Searching for flights from YYZ to YWG...
# Found 19 flights from YYZ to YWG.
# [6/870] Searching for flights from YYZ to YHZ...
# Found 45 flights from YYZ to YHZ.
# [7/870] Searching for flights from YYZ to YQB...
# Found 41 flights from YYZ to YQB.
# [8/870] Searching for flights from YYZ to YXE...
# Found 9 flights from YYZ to YXE.
# [9/870] Searching for flights from YYZ to YLW...
# Found 4 flights from YYZ to YLW.
# [10/870] Searching for flights from YYZ to YYJ...
# Found 5 flights from YYZ to YYJ.
# [11/870] Searching for flights from YYZ to YQR...
# Found 1 flights from YYZ to YQR.
# [12/870] Searching for flights from YYZ to YYT...
# Found 6 flights from YYZ to YYT.
# [13/870] Searching for flights from YYZ to YQT...
# Found 6 flights from YYZ to YQT.
# [14/870] Searching for flights from YYZ to YXU...
# No flights found from YYZ to YXU.
# [15/870] Searching for flights from YYZ to YYG...
# Found 1 flights from YYZ to YYG.
# [16/870] Searching for flights from YYZ to YQM...
# Found 5 flights from YYZ to YQM.
# [17/870] Searching for flights from YYZ to YXY...
# No flights found from YYZ to YXY.
# [18/870] Searching for flights from YYZ to YMM...
# No flights found from YYZ to YMM.
# [19/870] Searching for flights from YYZ to YKA...
# No flights found from YYZ to YKA.
# [20/870] Searching for flights from YYZ to YFC...
# No flights found from YYZ to YFC.
# [21/870] Searching for flights from YYZ to YZF...
# No flights found from YYZ to YZF.
# [22/870] Searching for flights from YYZ to YXS...
# No flights found from YYZ to YXS.
# [23/870] Searching for flights from YYZ to YDF...
# No flights found from YYZ to YDF.
# [24/870] Searching for flights from YYZ to YFB...
# No flights found from YYZ to YFB.
# [25/870] Searching for flights from YYZ to YQU...
# No flights found from YYZ to YQU.
# [26/870] Searching for flights from YYZ to YZP...
# No flights found from YYZ to YZP.
# [27/870] Searching for flights from YYZ to YVM...
# No flights found from YYZ to YVM.
# [28/870] Searching for flights from YYZ to YAX...
# No flights found from YYZ to YAX.
# [29/870] Searching for flights from YVR to YYZ...
# Found 67 flights from YVR to YYZ.
# [30/870] Searching for flights from YVR to YUL...
# Found 22 flights from YVR to YUL.
# [31/870] Searching for flights from YVR to YYC...
# Found 69 flights from YVR to YYC.
# [32/870] Searching for flights from YVR to YEG...
# Found 26 flights from YVR to YEG.
# [33/870] Searching for flights from YVR to YOW...
# Found 10 flights from YVR to YOW.
# [34/870] Searching for flights from YVR to YWG...
# Found 10 flights from YVR to YWG.
# [35/870] Searching for flights from YVR to YHZ...
# No flights found from YVR to YHZ.
# [36/870] Searching for flights from YVR to YQB...
# Found 1 flights from YVR to YQB.
# [37/870] Searching for flights from YVR to YXE...
# Found 8 flights from YVR to YXE.
# [38/870] Searching for flights from YVR to YLW...
# Found 23 flights from YVR to YLW.
# [39/870] Searching for flights from YVR to YYJ...
# Found 9 flights from YVR to YYJ.
# [40/870] Searching for flights from YVR to YQR...
# Found 1 flights from YVR to YQR.
# [41/870] Searching for flights from YVR to YYT...
# No flights found from YVR to YYT.
# [42/870] Searching for flights from YVR to YQT...
# No flights found from YVR to YQT.
# [43/870] Searching for flights from YVR to YXU...
# No flights found from YVR to YXU.
# [44/870] Searching for flights from YVR to YYG...
# No flights found from YVR to YYG.
# [45/870] Searching for flights from YVR to YQM...
# No flights found from YVR to YQM.
# [46/870] Searching for flights from YVR to YXY...
# Found 3 flights from YVR to YXY.
# [47/870] Searching for flights from YVR to YMM...
# No flights found from YVR to YMM.
# [48/870] Searching for flights from YVR to YKA...
# No flights found from YVR to YKA.
# [49/870] Searching for flights from YVR to YFC...
# No flights found from YVR to YFC.
# [50/870] Searching for flights from YVR to YZF...
# No flights found from YVR to YZF.
# [51/870] Searching for flights from YVR to YXS...
# Found 38 flights from YVR to YXS.
# [52/870] Searching for flights from YVR to YDF...
# No flights found from YVR to YDF.
# [53/870] Searching for flights from YVR to YFB...
# No flights found from YVR to YFB.
# [54/870] Searching for flights from YVR to YQU...
# No flights found from YVR to YQU.
# [55/870] Searching for flights from YVR to YZP...
# Found 2 flights from YVR to YZP.
# [56/870] Searching for flights from YVR to YVM...
# No flights found from YVR to YVM.
# [57/870] Searching for flights from YVR to YAX...
# No flights found from YVR to YAX.
# [58/870] Searching for flights from YUL to YYZ...
# Found 87 flights from YUL to YYZ.
# [59/870] Searching for flights from YUL to YVR...
# Found 37 flights from YUL to YVR.
# [60/870] Searching for flights from YUL to YYC...
# Found 15 flights from YUL to YYC.
# [61/870] Searching for flights from YUL to YEG...
# Found 5 flights from YUL to YEG.
# [62/870] Searching for flights from YUL to YOW...
# Found 19 flights from YUL to YOW.
# [63/870] Searching for flights from YUL to YWG...
# Found 8 flights from YUL to YWG.
# [64/870] Searching for flights from YUL to YHZ...
# Found 20 flights from YUL to YHZ.
# [65/870] Searching for flights from YUL to YQB...
# Found 27 flights from YUL to YQB.
# [66/870] Searching for flights from YUL to YXE...
# No flights found from YUL to YXE.
# [67/870] Searching for flights from YUL to YLW...
# Found 1 flights from YUL to YLW.
# [68/870] Searching for flights from YUL to YYJ...
# No flights found from YUL to YYJ.
# [69/870] Searching for flights from YUL to YQR...
# No flights found from YUL to YQR.
# [70/870] Searching for flights from YUL to YYT...
# Found 3 flights from YUL to YYT.
# [71/870] Searching for flights from YUL to YQT...
# No flights found from YUL to YQT.
# [72/870] Searching for flights from YUL to YXU...
# No flights found from YUL to YXU.
# [73/870] Searching for flights from YUL to YYG...
# Found 2 flights from YUL to YYG.
# [74/870] Searching for flights from YUL to YQM...
# Found 5 flights from YUL to YQM.
# [75/870] Searching for flights from YUL to YXY...
# No flights found from YUL to YXY.
# [76/870] Searching for flights from YUL to YMM...
# No flights found from YUL to YMM.
# [77/870] Searching for flights from YUL to YKA...
# No flights found from YUL to YKA.
# [78/870] Searching for flights from YUL to YFC...
# Found 5 flights from YUL to YFC.
# [79/870] Searching for flights from YUL to YZF...
# No flights found from YUL to YZF.
# [80/870] Searching for flights from YUL to YXS...
# No flights found from YUL to YXS.
# [81/870] Searching for flights from YUL to YDF...
# Found 2 flights from YUL to YDF.
# [82/870] Searching for flights from YUL to YFB...
# No flights found from YUL to YFB.
# [83/870] Searching for flights from YUL to YQU...
# No flights found from YUL to YQU.
# [84/870] Searching for flights from YUL to YZP...
# No flights found from YUL to YZP.
# [85/870] Searching for flights from YUL to YVM...
# No flights found from YUL to YVM.
# [86/870] Searching for flights from YUL to YAX...
# No flights found from YUL to YAX.
# [87/870] Searching for flights from YYC to YYZ...
# Found 91 flights from YYC to YYZ.
# [88/870] Searching for flights from YYC to YVR...
# Found 72 flights from YYC to YVR.
# [89/870] Searching for flights from YYC to YUL...
# Found 34 flights from YYC to YUL.
# [90/870] Searching for flights from YYC to YEG...
# Found 24 flights from YYC to YEG.
# [91/870] Searching for flights from YYC to YOW...
# Found 9 flights from YYC to YOW.
# [92/870] Searching for flights from YYC to YWG...
# Found 11 flights from YYC to YWG.
# [93/870] Searching for flights from YYC to YHZ...
# Found 2 flights from YYC to YHZ.
# [94/870] Searching for flights from YYC to YQB...
# No flights found from YYC to YQB.
# [95/870] Searching for flights from YYC to YXE...
# Found 18 flights from YYC to YXE.
# [96/870] Searching for flights from YYC to YLW...
# Found 16 flights from YYC to YLW.
# [97/870] Searching for flights from YYC to YYJ...
# Found 3 flights from YYC to YYJ.
# [98/870] Searching for flights from YYC to YQR...
# Found 10 flights from YYC to YQR.
# [99/870] Searching for flights from YYC to YYT...
# Found 1 flights from YYC to YYT.
# [100/870] Searching for flights from YYC to YQT...
# No flights found from YYC to YQT.
# [101/870] Searching for flights from YYC to YXU...
# No flights found from YYC to YXU.
# [102/870] Searching for flights from YYC to YYG...
# No flights found from YYC to YYG.
# [103/870] Searching for flights from YYC to YQM...
# Found 2 flights from YYC to YQM.
# [104/870] Searching for flights from YYC to YXY...
# No flights found from YYC to YXY.
# [105/870] Searching for flights from YYC to YMM...
# Found 8 flights from YYC to YMM.
# [106/870] Searching for flights from YYC to YKA...
# Found 4 flights from YYC to YKA.
# [107/870] Searching for flights from YYC to YFC...
# No flights found from YYC to YFC.
# [108/870] Searching for flights from YYC to YZF...
# Found 3 flights from YYC to YZF.
# [109/870] Searching for flights from YYC to YXS...
# Found 1 flights from YYC to YXS.
# [110/870] Searching for flights from YYC to YDF...
# No flights found from YYC to YDF.
# [111/870] Searching for flights from YYC to YFB...
# No flights found from YYC to YFB.
# [112/870] Searching for flights from YYC to YQU...
# Found 5 flights from YYC to YQU.
# [113/870] Searching for flights from YYC to YZP...
# No flights found from YYC to YZP.
# [114/870] Searching for flights from YYC to YVM...
# No flights found from YYC to YVM.
# [115/870] Searching for flights from YYC to YAX...
# No flights found from YYC to YAX.
# [116/870] Searching for flights from YEG to YYZ...
# Found 48 flights from YEG to YYZ.
# [117/870] Searching for flights from YEG to YVR...
# Found 29 flights from YEG to YVR.
# [118/870] Searching for flights from YEG to YUL...
# Found 9 flights from YEG to YUL.
# [119/870] Searching for flights from YEG to YYC...
# Found 31 flights from YEG to YYC.
# [120/870] Searching for flights from YEG to YOW...
# No flights found from YEG to YOW.
# [121/870] Searching for flights from YEG to YWG...
# Found 3 flights from YEG to YWG.
# [122/870] Searching for flights from YEG to YHZ...
# Found 1 flights from YEG to YHZ.
# [123/870] Searching for flights from YEG to YQB...
# No flights found from YEG to YQB.
# [124/870] Searching for flights from YEG to YXE...
# No flights found from YEG to YXE.
# [125/870] Searching for flights from YEG to YLW...
# Found 1 flights from YEG to YLW.
# [126/870] Searching for flights from YEG to YYJ...
# Found 2 flights from YEG to YYJ.
# [127/870] Searching for flights from YEG to YQR...
# Found 1 flights from YEG to YQR.
# [128/870] Searching for flights from YEG to YYT...
# No flights found from YEG to YYT.
# [129/870] Searching for flights from YEG to YQT...
# No flights found from YEG to YQT.
# [130/870] Searching for flights from YEG to YXU...
# No flights found from YEG to YXU.
# [131/870] Searching for flights from YEG to YYG...
# No flights found from YEG to YYG.
# [132/870] Searching for flights from YEG to YQM...
# No flights found from YEG to YQM.
# [133/870] Searching for flights from YEG to YXY...
# No flights found from YEG to YXY.
# [134/870] Searching for flights from YEG to YMM...
# No flights found from YEG to YMM.
# [135/870] Searching for flights from YEG to YKA...
# No flights found from YEG to YKA.
# [136/870] Searching for flights from YEG to YFC...
# No flights found from YEG to YFC.
# [137/870] Searching for flights from YEG to YZF...
# Found 2 flights from YEG to YZF.
# [138/870] Searching for flights from YEG to YXS...
# Found 1 flights from YEG to YXS.
# [139/870] Searching for flights from YEG to YDF...
# No flights found from YEG to YDF.
# [140/870] Searching for flights from YEG to YFB...
# No flights found from YEG to YFB.
# [141/870] Searching for flights from YEG to YQU...
# No flights found from YEG to YQU.
# [142/870] Searching for flights from YEG to YZP...
# No flights found from YEG to YZP.
# [143/870] Searching for flights from YEG to YVM...
# No flights found from YEG to YVM.
# [144/870] Searching for flights from YEG to YAX...
# No flights found from YEG to YAX.
# [145/870] Searching for flights from YOW to YYZ...
# Found 58 flights from YOW to YYZ.
# [146/870] Searching for flights from YOW to YVR...
# Found 18 flights from YOW to YVR.
# [147/870] Searching for flights from YOW to YUL...
# Found 20 flights from YOW to YUL.
# [148/870] Searching for flights from YOW to YYC...
# Found 6 flights from YOW to YYC.
# [149/870] Searching for flights from YOW to YEG...
# Found 4 flights from YOW to YEG.
# [150/870] Searching for flights from YOW to YWG...
# Found 1 flights from YOW to YWG.
# [151/870] Searching for flights from YOW to YHZ...
# Found 10 flights from YOW to YHZ.
# [152/870] Searching for flights from YOW to YQB...
# Found 1 flights from YOW to YQB.
# [153/870] Searching for flights from YOW to YXE...
# No flights found from YOW to YXE.
# [154/870] Searching for flights from YOW to YLW...
# No flights found from YOW to YLW.
# [155/870] Searching for flights from YOW to YYJ...
# No flights found from YOW to YYJ.
# [156/870] Searching for flights from YOW to YQR...
# No flights found from YOW to YQR.
# [157/870] Searching for flights from YOW to YYT...
# Found 2 flights from YOW to YYT.
# [158/870] Searching for flights from YOW to YQT...
# Found 2 flights from YOW to YQT.
# [159/870] Searching for flights from YOW to YXU...
# No flights found from YOW to YXU.
# [160/870] Searching for flights from YOW to YYG...
# Found 4 flights from YOW to YYG.
# [161/870] Searching for flights from YOW to YQM...
# Found 7 flights from YOW to YQM.
# [162/870] Searching for flights from YOW to YXY...
# No flights found from YOW to YXY.
# [163/870] Searching for flights from YOW to YMM...
# No flights found from YOW to YMM.
# [164/870] Searching for flights from YOW to YKA...
# No flights found from YOW to YKA.
# [165/870] Searching for flights from YOW to YFC...
# Found 4 flights from YOW to YFC.
# [166/870] Searching for flights from YOW to YZF...
# No flights found from YOW to YZF.
# [167/870] Searching for flights from YOW to YXS...
# No flights found from YOW to YXS.
# [168/870] Searching for flights from YOW to YDF...
# No flights found from YOW to YDF.
# [169/870] Searching for flights from YOW to YFB...
# Found 1 flights from YOW to YFB.
# [170/870] Searching for flights from YOW to YQU...
# No flights found from YOW to YQU.
# [171/870] Searching for flights from YOW to YZP...
# No flights found from YOW to YZP.
# [172/870] Searching for flights from YOW to YVM...
# No flights found from YOW to YVM.
# [173/870] Searching for flights from YOW to YAX...
# No flights found from YOW to YAX.
# [174/870] Searching for flights from YWG to YYZ...
# Found 52 flights from YWG to YYZ.
# [175/870] Searching for flights from YWG to YVR...
# Found 5 flights from YWG to YVR.
# [176/870] Searching for flights from YWG to YUL...
# Found 9 flights from YWG to YUL.
# [177/870] Searching for flights from YWG to YYC...
# Found 24 flights from YWG to YYC.
# [178/870] Searching for flights from YWG to YEG...
# Found 6 flights from YWG to YEG.
# [179/870] Searching for flights from YWG to YOW...
# Found 3 flights from YWG to YOW.
# [180/870] Searching for flights from YWG to YHZ...
# Found 1 flights from YWG to YHZ.
# [181/870] Searching for flights from YWG to YQB...
# No flights found from YWG to YQB.
# [182/870] Searching for flights from YWG to YXE...
# Found 3 flights from YWG to YXE.
# [183/870] Searching for flights from YWG to YLW...
# No flights found from YWG to YLW.
# [184/870] Searching for flights from YWG to YYJ...
# Found 1 flights from YWG to YYJ.
# [185/870] Searching for flights from YWG to YQR...
# No flights found from YWG to YQR.
# [186/870] Searching for flights from YWG to YYT...
# No flights found from YWG to YYT.
# [187/870] Searching for flights from YWG to YQT...
# Found 1 flights from YWG to YQT.
# [188/870] Searching for flights from YWG to YXU...
# No flights found from YWG to YXU.
# [189/870] Searching for flights from YWG to YYG...
# No flights found from YWG to YYG.
# [190/870] Searching for flights from YWG to YQM...
# No flights found from YWG to YQM.
# [191/870] Searching for flights from YWG to YXY...
# No flights found from YWG to YXY.
# [192/870] Searching for flights from YWG to YMM...
# No flights found from YWG to YMM.
# [193/870] Searching for flights from YWG to YKA...
# No flights found from YWG to YKA.
# [194/870] Searching for flights from YWG to YFC...
# No flights found from YWG to YFC.
# [195/870] Searching for flights from YWG to YZF...
# No flights found from YWG to YZF.
# [196/870] Searching for flights from YWG to YXS...
# No flights found from YWG to YXS.
# [197/870] Searching for flights from YWG to YDF...
# No flights found from YWG to YDF.
# [198/870] Searching for flights from YWG to YFB...
# No flights found from YWG to YFB.
# [199/870] Searching for flights from YWG to YQU...
# No flights found from YWG to YQU.
# [200/870] Searching for flights from YWG to YZP...
# No flights found from YWG to YZP.
# [201/870] Searching for flights from YWG to YVM...
# No flights found from YWG to YVM.
# [202/870] Searching for flights from YWG to YAX...
# No flights found from YWG to YAX.
# [203/870] Searching for flights from YHZ to YYZ...
# Found 46 flights from YHZ to YYZ.
# [204/870] Searching for flights from YHZ to YVR...
# Found 1 flights from YHZ to YVR.
# [205/870] Searching for flights from YHZ to YUL...
# Found 21 flights from YHZ to YUL.
# [206/870] Searching for flights from YHZ to YYC...
# Found 3 flights from YHZ to YYC.
# [207/870] Searching for flights from YHZ to YEG...
# No flights found from YHZ to YEG.
# [208/870] Searching for flights from YHZ to YOW...
# Found 5 flights from YHZ to YOW.
# [209/870] Searching for flights from YHZ to YWG...
# No flights found from YHZ to YWG.
# [210/870] Searching for flights from YHZ to YQB...
# No flights found from YHZ to YQB.
# [211/870] Searching for flights from YHZ to YXE...
# No flights found from YHZ to YXE.
# [212/870] Searching for flights from YHZ to YLW...
# No flights found from YHZ to YLW.
# [213/870] Searching for flights from YHZ to YYJ...
# No flights found from YHZ to YYJ.
# [214/870] Searching for flights from YHZ to YQR...
# No flights found from YHZ to YQR.
# [215/870] Searching for flights from YHZ to YYT...
# Found 5 flights from YHZ to YYT.
# [216/870] Searching for flights from YHZ to YQT...
# No flights found from YHZ to YQT.
# [217/870] Searching for flights from YHZ to YXU...
# No flights found from YHZ to YXU.
# [218/870] Searching for flights from YHZ to YYG...
# No flights found from YHZ to YYG.
# [219/870] Searching for flights from YHZ to YQM...
# No flights found from YHZ to YQM.
# [220/870] Searching for flights from YHZ to YXY...
# No flights found from YHZ to YXY.
# [221/870] Searching for flights from YHZ to YMM...
# No flights found from YHZ to YMM.
# [222/870] Searching for flights from YHZ to YKA...
# No flights found from YHZ to YKA.
# [223/870] Searching for flights from YHZ to YFC...
# No flights found from YHZ to YFC.
# [224/870] Searching for flights from YHZ to YZF...
# No flights found from YHZ to YZF.
# [225/870] Searching for flights from YHZ to YXS...
# No flights found from YHZ to YXS.
# [226/870] Searching for flights from YHZ to YDF...
# Found 2 flights from YHZ to YDF.
# [227/870] Searching for flights from YHZ to YFB...
# No flights found from YHZ to YFB.
# [228/870] Searching for flights from YHZ to YQU...
# No flights found from YHZ to YQU.
# [229/870] Searching for flights from YHZ to YZP...
# No flights found from YHZ to YZP.
# [230/870] Searching for flights from YHZ to YVM...
# No flights found from YHZ to YVM.
# [231/870] Searching for flights from YHZ to YAX...
# No flights found from YHZ to YAX.
# [232/870] Searching for flights from YQB to YYZ...
# Found 37 flights from YQB to YYZ.
# [233/870] Searching for flights from YQB to YVR...
# No flights found from YQB to YVR.
# [234/870] Searching for flights from YQB to YUL...
# Found 12 flights from YQB to YUL.
# [235/870] Searching for flights from YQB to YYC...
# No flights found from YQB to YYC.
# [236/870] Searching for flights from YQB to YEG...
# No flights found from YQB to YEG.
# [237/870] Searching for flights from YQB to YOW...
# Found 1 flights from YQB to YOW.
# [238/870] Searching for flights from YQB to YWG...
# No flights found from YQB to YWG.
# [239/870] Searching for flights from YQB to YHZ...
# No flights found from YQB to YHZ.
# [240/870] Searching for flights from YQB to YXE...
# No flights found from YQB to YXE.
# [241/870] Searching for flights from YQB to YLW...
# No flights found from YQB to YLW.
# [242/870] Searching for flights from YQB to YYJ...
# No flights found from YQB to YYJ.
# [243/870] Searching for flights from YQB to YQR...
# No flights found from YQB to YQR.
# [244/870] Searching for flights from YQB to YYT...
# No flights found from YQB to YYT.
# [245/870] Searching for flights from YQB to YQT...
# No flights found from YQB to YQT.
# [246/870] Searching for flights from YQB to YXU...
# No flights found from YQB to YXU.
# [247/870] Searching for flights from YQB to YYG...
# No flights found from YQB to YYG.
# [248/870] Searching for flights from YQB to YQM...
# No flights found from YQB to YQM.
# [249/870] Searching for flights from YQB to YXY...
# No flights found from YQB to YXY.
# [250/870] Searching for flights from YQB to YMM...
# No flights found from YQB to YMM.
# [251/870] Searching for flights from YQB to YKA...
# No flights found from YQB to YKA.
# [252/870] Searching for flights from YQB to YFC...
# Found 1 flights from YQB to YFC.
# [253/870] Searching for flights from YQB to YZF...
# No flights found from YQB to YZF.
# [254/870] Searching for flights from YQB to YXS...
# No flights found from YQB to YXS.
# [255/870] Searching for flights from YQB to YDF...
# No flights found from YQB to YDF.
# [256/870] Searching for flights from YQB to YFB...
# No flights found from YQB to YFB.
# [257/870] Searching for flights from YQB to YQU...
# No flights found from YQB to YQU.
# [258/870] Searching for flights from YQB to YZP...
# No flights found from YQB to YZP.
# [259/870] Searching for flights from YQB to YVM...
# No flights found from YQB to YVM.
# [260/870] Searching for flights from YQB to YAX...
# No flights found from YQB to YAX.
# [261/870] Searching for flights from YXE to YYZ...
# Found 16 flights from YXE to YYZ.
# [262/870] Searching for flights from YXE to YVR...
# Found 2 flights from YXE to YVR.
# [263/870] Searching for flights from YXE to YUL...
# Found 1 flights from YXE to YUL.
# [264/870] Searching for flights from YXE to YYC...
# Found 20 flights from YXE to YYC.
# [265/870] Searching for flights from YXE to YEG...
# Found 1 flights from YXE to YEG.
# [266/870] Searching for flights from YXE to YOW...
# No flights found from YXE to YOW.
# [267/870] Searching for flights from YXE to YWG...
# Found 2 flights from YXE to YWG.
# [268/870] Searching for flights from YXE to YHZ...
# No flights found from YXE to YHZ.
# [269/870] Searching for flights from YXE to YQB...
# No flights found from YXE to YQB.
# [270/870] Searching for flights from YXE to YLW...
# No flights found from YXE to YLW.
# [271/870] Searching for flights from YXE to YYJ...
# No flights found from YXE to YYJ.
# [272/870] Searching for flights from YXE to YQR...
# No flights found from YXE to YQR.
# [273/870] Searching for flights from YXE to YYT...
# No flights found from YXE to YYT.
# [274/870] Searching for flights from YXE to YQT...
# No flights found from YXE to YQT.
# [275/870] Searching for flights from YXE to YXU...
# No flights found from YXE to YXU.
# [276/870] Searching for flights from YXE to YYG...
# No flights found from YXE to YYG.
# [277/870] Searching for flights from YXE to YQM...
# No flights found from YXE to YQM.
# [278/870] Searching for flights from YXE to YXY...
# No flights found from YXE to YXY.
# [279/870] Searching for flights from YXE to YMM...
# No flights found from YXE to YMM.
# [280/870] Searching for flights from YXE to YKA...
# No flights found from YXE to YKA.
# [281/870] Searching for flights from YXE to YFC...
# No flights found from YXE to YFC.
# [282/870] Searching for flights from YXE to YZF...
# No flights found from YXE to YZF.
# [283/870] Searching for flights from YXE to YXS...
# No flights found from YXE to YXS.
# [284/870] Searching for flights from YXE to YDF...
# No flights found from YXE to YDF.
# [285/870] Searching for flights from YXE to YFB...
# No flights found from YXE to YFB.
# [286/870] Searching for flights from YXE to YQU...
# No flights found from YXE to YQU.
# [287/870] Searching for flights from YXE to YZP...
# No flights found from YXE to YZP.
# [288/870] Searching for flights from YXE to YVM...
# No flights found from YXE to YVM.
# [289/870] Searching for flights from YXE to YAX...
# No flights found from YXE to YAX.
# [290/870] Searching for flights from YLW to YYZ...
# No flights found from YLW to YYZ.
# [291/870] Searching for flights from YLW to YVR...
# Found 30 flights from YLW to YVR.
# [292/870] Searching for flights from YLW to YUL...
# No flights found from YLW to YUL.
# [293/870] Searching for flights from YLW to YYC...
# Found 20 flights from YLW to YYC.
# [294/870] Searching for flights from YLW to YEG...
# Found 3 flights from YLW to YEG.
# [295/870] Searching for flights from YLW to YOW...
# No flights found from YLW to YOW.
# [296/870] Searching for flights from YLW to YWG...
# No flights found from YLW to YWG.
# [297/870] Searching for flights from YLW to YHZ...
# No flights found from YLW to YHZ.
# [298/870] Searching for flights from YLW to YQB...
# No flights found from YLW to YQB.
# [299/870] Searching for flights from YLW to YXE...
# No flights found from YLW to YXE.
# [300/870] Searching for flights from YLW to YYJ...
# Found 3 flights from YLW to YYJ.
# [301/870] Searching for flights from YLW to YQR...
# No flights found from YLW to YQR.
# [302/870] Searching for flights from YLW to YYT...
# No flights found from YLW to YYT.
# [303/870] Searching for flights from YLW to YQT...
# No flights found from YLW to YQT.
# [304/870] Searching for flights from YLW to YXU...
# No flights found from YLW to YXU.
# [305/870] Searching for flights from YLW to YYG...
# No flights found from YLW to YYG.
# [306/870] Searching for flights from YLW to YQM...
# No flights found from YLW to YQM.
# [307/870] Searching for flights from YLW to YXY...
# No flights found from YLW to YXY.
# [308/870] Searching for flights from YLW to YMM...
# No flights found from YLW to YMM.
# [309/870] Searching for flights from YLW to YKA...
# No flights found from YLW to YKA.
# [310/870] Searching for flights from YLW to YFC...
# No flights found from YLW to YFC.
# [311/870] Searching for flights from YLW to YZF...
# No flights found from YLW to YZF.
# [312/870] Searching for flights from YLW to YXS...
# Found 2 flights from YLW to YXS.
# [313/870] Searching for flights from YLW to YDF...
# No flights found from YLW to YDF.
# [314/870] Searching for flights from YLW to YFB...
# No flights found from YLW to YFB.
# [315/870] Searching for flights from YLW to YQU...
# No flights found from YLW to YQU.
# [316/870] Searching for flights from YLW to YZP...
# No flights found from YLW to YZP.
# [317/870] Searching for flights from YLW to YVM...
# No flights found from YLW to YVM.
# [318/870] Searching for flights from YLW to YAX...
# No flights found from YLW to YAX.
# [319/870] Searching for flights from YYJ to YYZ...
# Found 10 flights from YYJ to YYZ.
# [320/870] Searching for flights from YYJ to YVR...
# Found 69 flights from YYJ to YVR.
# [321/870] Searching for flights from YYJ to YUL...
# No flights found from YYJ to YUL.
# [322/870] Searching for flights from YYJ to YYC...
# Found 22 flights from YYJ to YYC.
# [323/870] Searching for flights from YYJ to YEG...
# Found 3 flights from YYJ to YEG.
# [324/870] Searching for flights from YYJ to YOW...
# Found 2 flights from YYJ to YOW.
# [325/870] Searching for flights from YYJ to YWG...
# No flights found from YYJ to YWG.
# [326/870] Searching for flights from YYJ to YHZ...
# No flights found from YYJ to YHZ.
# [327/870] Searching for flights from YYJ to YQB...
# No flights found from YYJ to YQB.
# [328/870] Searching for flights from YYJ to YXE...
# No flights found from YYJ to YXE.
# [329/870] Searching for flights from YYJ to YLW...
# Found 4 flights from YYJ to YLW.
# [330/870] Searching for flights from YYJ to YQR...
# No flights found from YYJ to YQR.
# [331/870] Searching for flights from YYJ to YYT...
# No flights found from YYJ to YYT.
# [332/870] Searching for flights from YYJ to YQT...
# No flights found from YYJ to YQT.
# [333/870] Searching for flights from YYJ to YXU...
# No flights found from YYJ to YXU.
# [334/870] Searching for flights from YYJ to YYG...
# No flights found from YYJ to YYG.
# [335/870] Searching for flights from YYJ to YQM...
# No flights found from YYJ to YQM.
# [336/870] Searching for flights from YYJ to YXY...
# No flights found from YYJ to YXY.
# [337/870] Searching for flights from YYJ to YMM...
# No flights found from YYJ to YMM.
# [338/870] Searching for flights from YYJ to YKA...
# Found 1 flights from YYJ to YKA.
# [339/870] Searching for flights from YYJ to YFC...
# No flights found from YYJ to YFC.
# [340/870] Searching for flights from YYJ to YZF...
# No flights found from YYJ to YZF.
# [341/870] Searching for flights from YYJ to YXS...
# Found 2 flights from YYJ to YXS.
# [342/870] Searching for flights from YYJ to YDF...
# No flights found from YYJ to YDF.
# [343/870] Searching for flights from YYJ to YFB...
# No flights found from YYJ to YFB.
# [344/870] Searching for flights from YYJ to YQU...
# No flights found from YYJ to YQU.
# [345/870] Searching for flights from YYJ to YZP...
# No flights found from YYJ to YZP.
# [346/870] Searching for flights from YYJ to YVM...
# No flights found from YYJ to YVM.
# [347/870] Searching for flights from YYJ to YAX...
# No flights found from YYJ to YAX.
# [348/870] Searching for flights from YQR to YYZ...
# Found 1 flights from YQR to YYZ.
# [349/870] Searching for flights from YQR to YVR...
# Found 3 flights from YQR to YVR.
# [350/870] Searching for flights from YQR to YUL...
# No flights found from YQR to YUL.
# [351/870] Searching for flights from YQR to YYC...
# Found 18 flights from YQR to YYC.
# [352/870] Searching for flights from YQR to YEG...
# Found 2 flights from YQR to YEG.
# [353/870] Searching for flights from YQR to YOW...
# No flights found from YQR to YOW.
# [354/870] Searching for flights from YQR to YWG...
# No flights found from YQR to YWG.
# [355/870] Searching for flights from YQR to YHZ...
# No flights found from YQR to YHZ.
# [356/870] Searching for flights from YQR to YQB...
# No flights found from YQR to YQB.
# [357/870] Searching for flights from YQR to YXE...
# No flights found from YQR to YXE.
# [358/870] Searching for flights from YQR to YLW...
# No flights found from YQR to YLW.
# [359/870] Searching for flights from YQR to YYJ...
# No flights found from YQR to YYJ.
# [360/870] Searching for flights from YQR to YYT...
# No flights found from YQR to YYT.
# [361/870] Searching for flights from YQR to YQT...
# No flights found from YQR to YQT.
# [362/870] Searching for flights from YQR to YXU...
# No flights found from YQR to YXU.
# [363/870] Searching for flights from YQR to YYG...
# No flights found from YQR to YYG.
# [364/870] Searching for flights from YQR to YQM...
# No flights found from YQR to YQM.
# [365/870] Searching for flights from YQR to YXY...
# No flights found from YQR to YXY.
# [366/870] Searching for flights from YQR to YMM...
# No flights found from YQR to YMM.
# [367/870] Searching for flights from YQR to YKA...
# No flights found from YQR to YKA.
# [368/870] Searching for flights from YQR to YFC...
# No flights found from YQR to YFC.
# [369/870] Searching for flights from YQR to YZF...
# No flights found from YQR to YZF.
# [370/870] Searching for flights from YQR to YXS...
# No flights found from YQR to YXS.
# [371/870] Searching for flights from YQR to YDF...
# No flights found from YQR to YDF.
# [372/870] Searching for flights from YQR to YFB...
# No flights found from YQR to YFB.
# [373/870] Searching for flights from YQR to YQU...
# No flights found from YQR to YQU.
# [374/870] Searching for flights from YQR to YZP...
# No flights found from YQR to YZP.
# [375/870] Searching for flights from YQR to YVM...
# No flights found from YQR to YVM.
# [376/870] Searching for flights from YQR to YAX...
# No flights found from YQR to YAX.
# [377/870] Searching for flights from YYT to YYZ...
# Found 17 flights from YYT to YYZ.
# [378/870] Searching for flights from YYT to YVR...
# No flights found from YYT to YVR.
# [379/870] Searching for flights from YYT to YUL...
# Found 7 flights from YYT to YUL.
# [380/870] Searching for flights from YYT to YYC...
# No flights found from YYT to YYC.
# [381/870] Searching for flights from YYT to YEG...
# No flights found from YYT to YEG.
# [382/870] Searching for flights from YYT to YOW...
# Found 2 flights from YYT to YOW.
# [383/870] Searching for flights from YYT to YWG...
# No flights found from YYT to YWG.
# [384/870] Searching for flights from YYT to YHZ...
# Found 2 flights from YYT to YHZ.
# [385/870] Searching for flights from YYT to YQB...
# No flights found from YYT to YQB.
# [386/870] Searching for flights from YYT to YXE...
# No flights found from YYT to YXE.
# [387/870] Searching for flights from YYT to YLW...
# No flights found from YYT to YLW.
# [388/870] Searching for flights from YYT to YYJ...
# No flights found from YYT to YYJ.
# [389/870] Searching for flights from YYT to YQR...
# No flights found from YYT to YQR.
# [390/870] Searching for flights from YYT to YQT...
# No flights found from YYT to YQT.
# [391/870] Searching for flights from YYT to YXU...
# No flights found from YYT to YXU.
# [392/870] Searching for flights from YYT to YYG...
# No flights found from YYT to YYG.
# [393/870] Searching for flights from YYT to YQM...
# No flights found from YYT to YQM.
# [394/870] Searching for flights from YYT to YXY...
# No flights found from YYT to YXY.
# [395/870] Searching for flights from YYT to YMM...
# No flights found from YYT to YMM.
# [396/870] Searching for flights from YYT to YKA...
# No flights found from YYT to YKA.
# [397/870] Searching for flights from YYT to YFC...
# No flights found from YYT to YFC.
# [398/870] Searching for flights from YYT to YZF...
# No flights found from YYT to YZF.
# [399/870] Searching for flights from YYT to YXS...
# No flights found from YYT to YXS.
# [400/870] Searching for flights from YYT to YDF...
# Found 1 flights from YYT to YDF.
# [401/870] Searching for flights from YYT to YFB...
# No flights found from YYT to YFB.
# [402/870] Searching for flights from YYT to YQU...
# No flights found from YYT to YQU.
# [403/870] Searching for flights from YYT to YZP...
# No flights found from YYT to YZP.
# [404/870] Searching for flights from YYT to YVM...
# No flights found from YYT to YVM.
# [405/870] Searching for flights from YYT to YAX...
# No flights found from YYT to YAX.
# [406/870] Searching for flights from YQT to YYZ...
# Found 10 flights from YQT to YYZ.
# [407/870] Searching for flights from YQT to YVR...
# No flights found from YQT to YVR.
# [408/870] Searching for flights from YQT to YUL...
# No flights found from YQT to YUL.
# [409/870] Searching for flights from YQT to YYC...
# No flights found from YQT to YYC.
# [410/870] Searching for flights from YQT to YEG...
# No flights found from YQT to YEG.
# [411/870] Searching for flights from YQT to YOW...
# No flights found from YQT to YOW.
# [412/870] Searching for flights from YQT to YWG...
# Found 1 flights from YQT to YWG.
# [413/870] Searching for flights from YQT to YHZ...
# No flights found from YQT to YHZ.
# [414/870] Searching for flights from YQT to YQB...
# No flights found from YQT to YQB.
# [415/870] Searching for flights from YQT to YXE...
# No flights found from YQT to YXE.
# [416/870] Searching for flights from YQT to YLW...
# No flights found from YQT to YLW.
# [417/870] Searching for flights from YQT to YYJ...
# No flights found from YQT to YYJ.
# [418/870] Searching for flights from YQT to YQR...
# No flights found from YQT to YQR.
# [419/870] Searching for flights from YQT to YYT...
# No flights found from YQT to YYT.
# [420/870] Searching for flights from YQT to YXU...
# No flights found from YQT to YXU.
# [421/870] Searching for flights from YQT to YYG...
# No flights found from YQT to YYG.
# [422/870] Searching for flights from YQT to YQM...
# No flights found from YQT to YQM.
# [423/870] Searching for flights from YQT to YXY...
# No flights found from YQT to YXY.
# [424/870] Searching for flights from YQT to YMM...
# No flights found from YQT to YMM.
# [425/870] Searching for flights from YQT to YKA...
# No flights found from YQT to YKA.
# [426/870] Searching for flights from YQT to YFC...
# No flights found from YQT to YFC.
# [427/870] Searching for flights from YQT to YZF...
# No flights found from YQT to YZF.
# [428/870] Searching for flights from YQT to YXS...
# No flights found from YQT to YXS.
# [429/870] Searching for flights from YQT to YDF...
# No flights found from YQT to YDF.
# [430/870] Searching for flights from YQT to YFB...
# No flights found from YQT to YFB.
# [431/870] Searching for flights from YQT to YQU...
# No flights found from YQT to YQU.
# [432/870] Searching for flights from YQT to YZP...
# No flights found from YQT to YZP.
# [433/870] Searching for flights from YQT to YVM...
# No flights found from YQT to YVM.
# [434/870] Searching for flights from YQT to YAX...
# No flights found from YQT to YAX.
# [435/870] Searching for flights from YXU to YYZ...
# Found 8 flights from YXU to YYZ.
# [436/870] Searching for flights from YXU to YVR...
# No flights found from YXU to YVR.
# [437/870] Searching for flights from YXU to YUL...
# No flights found from YXU to YUL.
# [438/870] Searching for flights from YXU to YYC...
# Found 1 flights from YXU to YYC.
# [439/870] Searching for flights from YXU to YEG...
# No flights found from YXU to YEG.
# [440/870] Searching for flights from YXU to YOW...
# No flights found from YXU to YOW.
# [441/870] Searching for flights from YXU to YWG...
# No flights found from YXU to YWG.
# [442/870] Searching for flights from YXU to YHZ...
# No flights found from YXU to YHZ.
# [443/870] Searching for flights from YXU to YQB...
# No flights found from YXU to YQB.
# [444/870] Searching for flights from YXU to YXE...
# No flights found from YXU to YXE.
# [445/870] Searching for flights from YXU to YLW...
# No flights found from YXU to YLW.
# [446/870] Searching for flights from YXU to YYJ...
# No flights found from YXU to YYJ.
# [447/870] Searching for flights from YXU to YQR...
# No flights found from YXU to YQR.
# [448/870] Searching for flights from YXU to YYT...
# No flights found from YXU to YYT.
# [449/870] Searching for flights from YXU to YQT...
# No flights found from YXU to YQT.
# [450/870] Searching for flights from YXU to YYG...
# No flights found from YXU to YYG.
# [451/870] Searching for flights from YXU to YQM...
# No flights found from YXU to YQM.
# [452/870] Searching for flights from YXU to YXY...
# No flights found from YXU to YXY.
# [453/870] Searching for flights from YXU to YMM...
# No flights found from YXU to YMM.
# [454/870] Searching for flights from YXU to YKA...
# No flights found from YXU to YKA.
# [455/870] Searching for flights from YXU to YFC...
# No flights found from YXU to YFC.
# [456/870] Searching for flights from YXU to YZF...
# No flights found from YXU to YZF.
# [457/870] Searching for flights from YXU to YXS...
# No flights found from YXU to YXS.
# [458/870] Searching for flights from YXU to YDF...
# No flights found from YXU to YDF.
# [459/870] Searching for flights from YXU to YFB...
# No flights found from YXU to YFB.
# [460/870] Searching for flights from YXU to YQU...
# No flights found from YXU to YQU.
# [461/870] Searching for flights from YXU to YZP...
# No flights found from YXU to YZP.
# [462/870] Searching for flights from YXU to YVM...
# No flights found from YXU to YVM.
# [463/870] Searching for flights from YXU to YAX...
# No flights found from YXU to YAX.
# [464/870] Searching for flights from YYG to YYZ...
# Found 3 flights from YYG to YYZ.
# [465/870] Searching for flights from YYG to YVR...
# No flights found from YYG to YVR.
# [466/870] Searching for flights from YYG to YUL...
# Found 6 flights from YYG to YUL.
# [467/870] Searching for flights from YYG to YYC...
# No flights found from YYG to YYC.
# [468/870] Searching for flights from YYG to YEG...
# No flights found from YYG to YEG.
# [469/870] Searching for flights from YYG to YOW...
# Found 2 flights from YYG to YOW.
# [470/870] Searching for flights from YYG to YWG...
# No flights found from YYG to YWG.
# [471/870] Searching for flights from YYG to YHZ...
# No flights found from YYG to YHZ.
# [472/870] Searching for flights from YYG to YQB...
# No flights found from YYG to YQB.
# [473/870] Searching for flights from YYG to YXE...
# No flights found from YYG to YXE.
# [474/870] Searching for flights from YYG to YLW...
# No flights found from YYG to YLW.
# [475/870] Searching for flights from YYG to YYJ...
# No flights found from YYG to YYJ.
# [476/870] Searching for flights from YYG to YQR...
# No flights found from YYG to YQR.
# [477/870] Searching for flights from YYG to YYT...
# No flights found from YYG to YYT.
# [478/870] Searching for flights from YYG to YQT...
# No flights found from YYG to YQT.
# [479/870] Searching for flights from YYG to YXU...
# No flights found from YYG to YXU.
# [480/870] Searching for flights from YYG to YQM...
# No flights found from YYG to YQM.
# [481/870] Searching for flights from YYG to YXY...
# No flights found from YYG to YXY.
# [482/870] Searching for flights from YYG to YMM...
# No flights found from YYG to YMM.
# [483/870] Searching for flights from YYG to YKA...
# No flights found from YYG to YKA.
# [484/870] Searching for flights from YYG to YFC...
# No flights found from YYG to YFC.
# [485/870] Searching for flights from YYG to YZF...
# No flights found from YYG to YZF.
# [486/870] Searching for flights from YYG to YXS...
# No flights found from YYG to YXS.
# [487/870] Searching for flights from YYG to YDF...
# No flights found from YYG to YDF.
# [488/870] Searching for flights from YYG to YFB...
# No flights found from YYG to YFB.
# [489/870] Searching for flights from YYG to YQU...
# No flights found from YYG to YQU.
# [490/870] Searching for flights from YYG to YZP...
# No flights found from YYG to YZP.
# [491/870] Searching for flights from YYG to YVM...
# No flights found from YYG to YVM.
# [492/870] Searching for flights from YYG to YAX...
# No flights found from YYG to YAX.
# [493/870] Searching for flights from YQM to YYZ...
# Found 5 flights from YQM to YYZ.
# [494/870] Searching for flights from YQM to YVR...
# No flights found from YQM to YVR.
# [495/870] Searching for flights from YQM to YUL...
# Found 8 flights from YQM to YUL.
# [496/870] Searching for flights from YQM to YYC...
# No flights found from YQM to YYC.
# [497/870] Searching for flights from YQM to YEG...
# No flights found from YQM to YEG.
# [498/870] Searching for flights from YQM to YOW...
# No flights found from YQM to YOW.
# [499/870] Searching for flights from YQM to YWG...
# No flights found from YQM to YWG.
# [500/870] Searching for flights from YQM to YHZ...
# No flights found from YQM to YHZ.
# [501/870] Searching for flights from YQM to YQB...
# No flights found from YQM to YQB.
# [502/870] Searching for flights from YQM to YXE...
# No flights found from YQM to YXE.
# [503/870] Searching for flights from YQM to YLW...
# No flights found from YQM to YLW.
# [504/870] Searching for flights from YQM to YYJ...
# No flights found from YQM to YYJ.
# [505/870] Searching for flights from YQM to YQR...
# No flights found from YQM to YQR.
# [506/870] Searching for flights from YQM to YYT...
# No flights found from YQM to YYT.
# [507/870] Searching for flights from YQM to YQT...
# No flights found from YQM to YQT.
# [508/870] Searching for flights from YQM to YXU...
# No flights found from YQM to YXU.
# [509/870] Searching for flights from YQM to YYG...
# No flights found from YQM to YYG.
# [510/870] Searching for flights from YQM to YXY...
# No flights found from YQM to YXY.
# [511/870] Searching for flights from YQM to YMM...
# No flights found from YQM to YMM.
# [512/870] Searching for flights from YQM to YKA...
# No flights found from YQM to YKA.
# [513/870] Searching for flights from YQM to YFC...
# No flights found from YQM to YFC.
# [514/870] Searching for flights from YQM to YZF...
# No flights found from YQM to YZF.
# [515/870] Searching for flights from YQM to YXS...
# No flights found from YQM to YXS.
# [516/870] Searching for flights from YQM to YDF...
# No flights found from YQM to YDF.
# [517/870] Searching for flights from YQM to YFB...
# No flights found from YQM to YFB.
# [518/870] Searching for flights from YQM to YQU...
# No flights found from YQM to YQU.
# [519/870] Searching for flights from YQM to YZP...
# No flights found from YQM to YZP.
# [520/870] Searching for flights from YQM to YVM...
# No flights found from YQM to YVM.
# [521/870] Searching for flights from YQM to YAX...
# No flights found from YQM to YAX.
# [522/870] Searching for flights from YXY to YYZ...
# No flights found from YXY to YYZ.
# [523/870] Searching for flights from YXY to YVR...
# Found 1 flights from YXY to YVR.
# [524/870] Searching for flights from YXY to YUL...
# No flights found from YXY to YUL.
# [525/870] Searching for flights from YXY to YYC...
# No flights found from YXY to YYC.
# [526/870] Searching for flights from YXY to YEG...
# No flights found from YXY to YEG.
# [527/870] Searching for flights from YXY to YOW...
# No flights found from YXY to YOW.
# [528/870] Searching for flights from YXY to YWG...
# No flights found from YXY to YWG.
# [529/870] Searching for flights from YXY to YHZ...
# No flights found from YXY to YHZ.
# [530/870] Searching for flights from YXY to YQB...
# No flights found from YXY to YQB.
# [531/870] Searching for flights from YXY to YXE...
# No flights found from YXY to YXE.
# [532/870] Searching for flights from YXY to YLW...
# No flights found from YXY to YLW.
# [533/870] Searching for flights from YXY to YYJ...
# No flights found from YXY to YYJ.
# [534/870] Searching for flights from YXY to YQR...
# No flights found from YXY to YQR.
# [535/870] Searching for flights from YXY to YYT...
# No flights found from YXY to YYT.
# [536/870] Searching for flights from YXY to YQT...
# No flights found from YXY to YQT.
# [537/870] Searching for flights from YXY to YXU...
# No flights found from YXY to YXU.
# [538/870] Searching for flights from YXY to YYG...
# No flights found from YXY to YYG.
# [539/870] Searching for flights from YXY to YQM...
# No flights found from YXY to YQM.
# [540/870] Searching for flights from YXY to YMM...
# No flights found from YXY to YMM.
# [541/870] Searching for flights from YXY to YKA...
# No flights found from YXY to YKA.
# [542/870] Searching for flights from YXY to YFC...
# No flights found from YXY to YFC.
# [543/870] Searching for flights from YXY to YZF...
# No flights found from YXY to YZF.
# [544/870] Searching for flights from YXY to YXS...
# No flights found from YXY to YXS.
# [545/870] Searching for flights from YXY to YDF...
# No flights found from YXY to YDF.
# [546/870] Searching for flights from YXY to YFB...
# No flights found from YXY to YFB.
# [547/870] Searching for flights from YXY to YQU...
# No flights found from YXY to YQU.
# [548/870] Searching for flights from YXY to YZP...
# No flights found from YXY to YZP.
# [549/870] Searching for flights from YXY to YVM...
# No flights found from YXY to YVM.
# [550/870] Searching for flights from YXY to YAX...
# No flights found from YXY to YAX.
# [551/870] Searching for flights from YMM to YYZ...
# No flights found from YMM to YYZ.
# [552/870] Searching for flights from YMM to YVR...
# No flights found from YMM to YVR.
# [553/870] Searching for flights from YMM to YUL...
# No flights found from YMM to YUL.
# [554/870] Searching for flights from YMM to YYC...
# Found 9 flights from YMM to YYC.
# [555/870] Searching for flights from YMM to YEG...
# No flights found from YMM to YEG.
# [556/870] Searching for flights from YMM to YOW...
# No flights found from YMM to YOW.
# [557/870] Searching for flights from YMM to YWG...
# No flights found from YMM to YWG.
# [558/870] Searching for flights from YMM to YHZ...
# No flights found from YMM to YHZ.
# [559/870] Searching for flights from YMM to YQB...
# No flights found from YMM to YQB.
# [560/870] Searching for flights from YMM to YXE...
# No flights found from YMM to YXE.
# [561/870] Searching for flights from YMM to YLW...
# No flights found from YMM to YLW.
# [562/870] Searching for flights from YMM to YYJ...
# No flights found from YMM to YYJ.
# [563/870] Searching for flights from YMM to YQR...
# No flights found from YMM to YQR.
# [564/870] Searching for flights from YMM to YYT...
# No flights found from YMM to YYT.
# [565/870] Searching for flights from YMM to YQT...
# No flights found from YMM to YQT.
# [566/870] Searching for flights from YMM to YXU...
# No flights found from YMM to YXU.
# ...
# No flights found from YXS to YXU.
# [683/870] Searching for flights from YXS to YYG...
# No flights found from YXS to YYG.
# [684/870] Searching for flights from YXS to YQM...
# No flights found from YXS to YQM.
# [685/870] Searching for flights from YXS to YXY...
# No flights found from YXS to YXY.
# [686/870] Searching for flights from YXS to YMM...
# No flights found from YXS to YMM.
# [687/870] Searching for flights from YXS to YKA...
# No flights found from YXS to YKA.
# [688/870] Searching for flights from YXS to YFC...
# No flights found from YXS to YFC.
# [689/870] Searching for flights from YXS to YZF...
# No flights found from YXS to YZF.
# [690/870] Searching for flights from YXS to YDF...
# No flights found from YXS to YDF.
# [691/870] Searching for flights from YXS to YFB...
# No flights found from YXS to YFB.
# [692/870] Searching for flights from YXS to YQU...
# No flights found from YXS to YQU.
# [693/870] Searching for flights from YXS to YZP...
# No flights found from YXS to YZP.
# [694/870] Searching for flights from YXS to YVM...
# No flights found from YXS to YVM.
# [695/870] Searching for flights from YXS to YAX...
# No flights found from YXS to YAX.
# [696/870] Searching for flights from YDF to YYZ...
# Found 3 flights from YDF to YYZ.
# [697/870] Searching for flights from YDF to YVR...
# No flights found from YDF to YVR.
# [698/870] Searching for flights from YDF to YUL...
# Found 2 flights from YDF to YUL.
# [699/870] Searching for flights from YDF to YYC...
# No flights found from YDF to YYC.
# [700/870] Searching for flights from YDF to YEG...
# No flights found from YDF to YEG.
# [701/870] Searching for flights from YDF to YOW...
# No flights found from YDF to YOW.
# [702/870] Searching for flights from YDF to YWG...
# No flights found from YDF to YWG.
# [703/870] Searching for flights from YDF to YHZ...
# No flights found from YDF to YHZ.
# [704/870] Searching for flights from YDF to YQB...
# No flights found from YDF to YQB.
# [705/870] Searching for flights from YDF to YXE...
# No flights found from YDF to YXE.
# [706/870] Searching for flights from YDF to YLW...
# No flights found from YDF to YLW.
# [707/870] Searching for flights from YDF to YYJ...
# No flights found from YDF to YYJ.
# [708/870] Searching for flights from YDF to YQR...
# No flights found from YDF to YQR.
# [709/870] Searching for flights from YDF to YYT...
# No flights found from YDF to YYT.
# [710/870] Searching for flights from YDF to YQT...
# No flights found from YDF to YQT.
# [711/870] Searching for flights from YDF to YXU...
# No flights found from YDF to YXU.
# [712/870] Searching for flights from YDF to YYG...
# No flights found from YDF to YYG.
# [713/870] Searching for flights from YDF to YQM...
# No flights found from YDF to YQM.
# [714/870] Searching for flights from YDF to YXY...
# No flights found from YDF to YXY.
# [715/870] Searching for flights from YDF to YMM...
# No flights found from YDF to YMM.
# [716/870] Searching for flights from YDF to YKA...
# No flights found from YDF to YKA.
# [717/870] Searching for flights from YDF to YFC...
# No flights found from YDF to YFC.
# [718/870] Searching for flights from YDF to YZF...
# No flights found from YDF to YZF.
# [719/870] Searching for flights from YDF to YXS...
# No flights found from YDF to YXS.
# [720/870] Searching for flights from YDF to YFB...
# No flights found from YDF to YFB.
# [721/870] Searching for flights from YDF to YQU...
# No flights found from YDF to YQU.
# [722/870] Searching for flights from YDF to YZP...
# No flights found from YDF to YZP.
# [723/870] Searching for flights from YDF to YVM...
# No flights found from YDF to YVM.
# [724/870] Searching for flights from YDF to YAX...
# No flights found from YDF to YAX.
# [725/870] Searching for flights from YFB to YYZ...
# No flights found from YFB to YYZ.
# [726/870] Searching for flights from YFB to YVR...
# No flights found from YFB to YVR.
# [727/870] Searching for flights from YFB to YUL...
# No flights found from YFB to YUL.
# [728/870] Searching for flights from YFB to YYC...
# Found 1 flights from YFB to YYC.
# [729/870] Searching for flights from YFB to YEG...
# No flights found from YFB to YEG.
# [730/870] Searching for flights from YFB to YOW...
# No flights found from YFB to YOW.
# [731/870] Searching for flights from YFB to YWG...
# No flights found from YFB to YWG.
# [732/870] Searching for flights from YFB to YHZ...
# No flights found from YFB to YHZ.
# [733/870] Searching for flights from YFB to YQB...
# No flights found from YFB to YQB.
# [734/870] Searching for flights from YFB to YXE...
# No flights found from YFB to YXE.
# [735/870] Searching for flights from YFB to YLW...
# No flights found from YFB to YLW.
# [736/870] Searching for flights from YFB to YYJ...
# No flights found from YFB to YYJ.
# [737/870] Searching for flights from YFB to YQR...
# No flights found from YFB to YQR.
# [738/870] Searching for flights from YFB to YYT...
# No flights found from YFB to YYT.
# [739/870] Searching for flights from YFB to YQT...
# No flights found from YFB to YQT.
# [740/870] Searching for flights from YFB to YXU...
# No flights found from YFB to YXU.
# [741/870] Searching for flights from YFB to YYG...
# No flights found from YFB to YYG.
# [742/870] Searching for flights from YFB to YQM...
# No flights found from YFB to YQM.
# [743/870] Searching for flights from YFB to YXY...
# No flights found from YFB to YXY.
# [744/870] Searching for flights from YFB to YMM...
# No flights found from YFB to YMM.
# [745/870] Searching for flights from YFB to YKA...
# No flights found from YFB to YKA.
# [746/870] Searching for flights from YFB to YFC...
# No flights found from YFB to YFC.
# [747/870] Searching for flights from YFB to YZF...
# No flights found from YFB to YZF.
# [748/870] Searching for flights from YFB to YXS...
# No flights found from YFB to YXS.
# [749/870] Searching for flights from YFB to YDF...
# No flights found from YFB to YDF.
# [750/870] Searching for flights from YFB to YQU...
# No flights found from YFB to YQU.
# [751/870] Searching for flights from YFB to YZP...
# No flights found from YFB to YZP.
# [752/870] Searching for flights from YFB to YVM...
# Found 1 flights from YFB to YVM.
# [753/870] Searching for flights from YFB to YAX...
# No flights found from YFB to YAX.
# [754/870] Searching for flights from YQU to YYZ...
# No flights found from YQU to YYZ.
# [755/870] Searching for flights from YQU to YVR...
# No flights found from YQU to YVR.
# [756/870] Searching for flights from YQU to YUL...
# No flights found from YQU to YUL.
# [757/870] Searching for flights from YQU to YYC...
# Found 8 flights from YQU to YYC.
# [758/870] Searching for flights from YQU to YEG...
# No flights found from YQU to YEG.
# [759/870] Searching for flights from YQU to YOW...
# No flights found from YQU to YOW.
# [760/870] Searching for flights from YQU to YWG...
# No flights found from YQU to YWG.
# [761/870] Searching for flights from YQU to YHZ...
# No flights found from YQU to YHZ.
# [762/870] Searching for flights from YQU to YQB...
# No flights found from YQU to YQB.
# [763/870] Searching for flights from YQU to YXE...
# No flights found from YQU to YXE.
# [764/870] Searching for flights from YQU to YLW...
# No flights found from YQU to YLW.
# [765/870] Searching for flights from YQU to YYJ...
# No flights found from YQU to YYJ.
# [766/870] Searching for flights from YQU to YQR...
# No flights found from YQU to YQR.
# [767/870] Searching for flights from YQU to YYT...
# No flights found from YQU to YYT.
# [768/870] Searching for flights from YQU to YQT...
# No flights found from YQU to YQT.
# [769/870] Searching for flights from YQU to YXU...
# No flights found from YQU to YXU.
# [770/870] Searching for flights from YQU to YYG...
# No flights found from YQU to YYG.
# [771/870] Searching for flights from YQU to YQM...
# No flights found from YQU to YQM.
# [772/870] Searching for flights from YQU to YXY...
# No flights found from YQU to YXY.
# [773/870] Searching for flights from YQU to YMM...
# No flights found from YQU to YMM.
# [774/870] Searching for flights from YQU to YKA...
# No flights found from YQU to YKA.
# [775/870] Searching for flights from YQU to YFC...
# No flights found from YQU to YFC.
# [776/870] Searching for flights from YQU to YZF...
# No flights found from YQU to YZF.
# [777/870] Searching for flights from YQU to YXS...
# No flights found from YQU to YXS.
# [778/870] Searching for flights from YQU to YDF...
# No flights found from YQU to YDF.
# [779/870] Searching for flights from YQU to YFB...
# No flights found from YQU to YFB.
# [780/870] Searching for flights from YQU to YZP...
# No flights found from YQU to YZP.
# [781/870] Searching for flights from YQU to YVM...
# No flights found from YQU to YVM.
# [782/870] Searching for flights from YQU to YAX...
# No flights found from YQU to YAX.
# [783/870] Searching for flights from YZP to YYZ...
# No flights found from YZP to YYZ.
# [784/870] Searching for flights from YZP to YVR...
# No flights found from YZP to YVR.
# [785/870] Searching for flights from YZP to YUL...
# No flights found from YZP to YUL.
# [786/870] Searching for flights from YZP to YYC...
# No flights found from YZP to YYC.
# [787/870] Searching for flights from YZP to YEG...
# No flights found from YZP to YEG.
# [788/870] Searching for flights from YZP to YOW...
# No flights found from YZP to YOW.
# [789/870] Searching for flights from YZP to YWG...
# No flights found from YZP to YWG.
# [790/870] Searching for flights from YZP to YHZ...
# No flights found from YZP to YHZ.
# [791/870] Searching for flights from YZP to YQB...
# No flights found from YZP to YQB.
# [792/870] Searching for flights from YZP to YXE...
# No flights found from YZP to YXE.
# [793/870] Searching for flights from YZP to YLW...
# No flights found from YZP to YLW.
# [794/870] Searching for flights from YZP to YYJ...
# No flights found from YZP to YYJ.
# [795/870] Searching for flights from YZP to YQR...
# No flights found from YZP to YQR.
# [796/870] Searching for flights from YZP to YYT...
# No flights found from YZP to YYT.
# [797/870] Searching for flights from YZP to YQT...
# No flights found from YZP to YQT.
# [798/870] Searching for flights from YZP to YXU...
# No flights found from YZP to YXU.
# [799/870] Searching for flights from YZP to YYG...
# No flights found from YZP to YYG.
# [800/870] Searching for flights from YZP to YQM...
# No flights found from YZP to YQM.
# [801/870] Searching for flights from YZP to YXY...
# No flights found from YZP to YXY.
# [802/870] Searching for flights from YZP to YMM...
# No flights found from YZP to YMM.
# [803/870] Searching for flights from YZP to YKA...
# No flights found from YZP to YKA.
# [804/870] Searching for flights from YZP to YFC...
# No flights found from YZP to YFC.
# [805/870] Searching for flights from YZP to YZF...
# No flights found from YZP to YZF.
# [806/870] Searching for flights from YZP to YXS...
# No flights found from YZP to YXS.
# [807/870] Searching for flights from YZP to YDF...
# No flights found from YZP to YDF.
# [808/870] Searching for flights from YZP to YFB...
# No flights found from YZP to YFB.
# [809/870] Searching for flights from YZP to YQU...
# No flights found from YZP to YQU.
# [810/870] Searching for flights from YZP to YVM...
# No flights found from YZP to YVM.
# [811/870] Searching for flights from YZP to YAX...
# No flights found from YZP to YAX.
# [812/870] Searching for flights from YVM to YYZ...
# No flights found from YVM to YYZ.
# [813/870] Searching for flights from YVM to YVR...
# No flights found from YVM to YVR.
# [814/870] Searching for flights from YVM to YUL...
# No flights found from YVM to YUL.
# [815/870] Searching for flights from YVM to YYC...
# No flights found from YVM to YYC.
# [816/870] Searching for flights from YVM to YEG...
# No flights found from YVM to YEG.
# [817/870] Searching for flights from YVM to YOW...
# No flights found from YVM to YOW.
# [818/870] Searching for flights from YVM to YWG...
# No flights found from YVM to YWG.
# [819/870] Searching for flights from YVM to YHZ...
# No flights found from YVM to YHZ.
# [820/870] Searching for flights from YVM to YQB...
# No flights found from YVM to YQB.
# [821/870] Searching for flights from YVM to YXE...
# No flights found from YVM to YXE.
# [822/870] Searching for flights from YVM to YLW...
# No flights found from YVM to YLW.
# [823/870] Searching for flights from YVM to YYJ...
# No flights found from YVM to YYJ.
# [824/870] Searching for flights from YVM to YQR...
# No flights found from YVM to YQR.
# [825/870] Searching for flights from YVM to YYT...
# No flights found from YVM to YYT.
# [826/870] Searching for flights from YVM to YQT...
# No flights found from YVM to YQT.
# [827/870] Searching for flights from YVM to YXU...
# No flights found from YVM to YXU.
# [828/870] Searching for flights from YVM to YYG...
# No flights found from YVM to YYG.
# [829/870] Searching for flights from YVM to YQM...
# No flights found from YVM to YQM.
# [830/870] Searching for flights from YVM to YXY...
# No flights found from YVM to YXY.
# [831/870] Searching for flights from YVM to YMM...
# No flights found from YVM to YMM.
# [832/870] Searching for flights from YVM to YKA...
# No flights found from YVM to YKA.
# [833/870] Searching for flights from YVM to YFC...
# No flights found from YVM to YFC.
# [834/870] Searching for flights from YVM to YZF...
# No flights found from YVM to YZF.
# [835/870] Searching for flights from YVM to YXS...
# No flights found from YVM to YXS.
# [836/870] Searching for flights from YVM to YDF...
# No flights found from YVM to YDF.
# [837/870] Searching for flights from YVM to YFB...
# No flights found from YVM to YFB.
# [838/870] Searching for flights from YVM to YQU...
# No flights found from YVM to YQU.
# [839/870] Searching for flights from YVM to YZP...
# No flights found from YVM to YZP.
# [840/870] Searching for flights from YVM to YAX...
# No flights found from YVM to YAX.
# [841/870] Searching for flights from YAX to YYZ...
# No flights found from YAX to YYZ.
# [842/870] Searching for flights from YAX to YVR...
# No flights found from YAX to YVR.
# [843/870] Searching for flights from YAX to YUL...
# No flights found from YAX to YUL.
# [844/870] Searching for flights from YAX to YYC...
# No flights found from YAX to YYC.
# [845/870] Searching for flights from YAX to YEG...
# No flights found from YAX to YEG.
# [846/870] Searching for flights from YAX to YOW...
# No flights found from YAX to YOW.
# [847/870] Searching for flights from YAX to YWG...
# No flights found from YAX to YWG.
# [848/870] Searching for flights from YAX to YHZ...
# No flights found from YAX to YHZ.
# [849/870] Searching for flights from YAX to YQB...
# No flights found from YAX to YQB.
# [850/870] Searching for flights from YAX to YXE...
# No flights found from YAX to YXE.
# [851/870] Searching for flights from YAX to YLW...
# No flights found from YAX to YLW.
# [852/870] Searching for flights from YAX to YYJ...
# No flights found from YAX to YYJ.
# [853/870] Searching for flights from YAX to YQR...
# No flights found from YAX to YQR.
# [854/870] Searching for flights from YAX to YYT...
# No flights found from YAX to YYT.
# [855/870] Searching for flights from YAX to YQT...
# No flights found from YAX to YQT.
# [856/870] Searching for flights from YAX to YXU...
# No flights found from YAX to YXU.
# [857/870] Searching for flights from YAX to YYG...
# No flights found from YAX to YYG.
# [858/870] Searching for flights from YAX to YQM...
# No flights found from YAX to YQM.
# [859/870] Searching for flights from YAX to YXY...
# No flights found from YAX to YXY.
# [860/870] Searching for flights from YAX to YMM...
# No flights found from YAX to YMM.
# [861/870] Searching for flights from YAX to YKA...
# No flights found from YAX to YKA.
# [862/870] Searching for flights from YAX to YFC...
# No flights found from YAX to YFC.
# [863/870] Searching for flights from YAX to YZF...
# No flights found from YAX to YZF.
# [864/870] Searching for flights from YAX to YXS...
# No flights found from YAX to YXS.
# [865/870] Searching for flights from YAX to YDF...
# No flights found from YAX to YDF.
# [866/870] Searching for flights from YAX to YFB...
# No flights found from YAX to YFB.
# [867/870] Searching for flights from YAX to YQU...
# No flights found from YAX to YQU.
# [868/870] Searching for flights from YAX to YZP...
# No flights found from YAX to YZP.
# [869/870] Searching for flights from YAX to YVM...
# No flights found from YAX to YVM.
# No flights were found during the search.

# %%
import pandas as pd
import csv

# Read the Canadian airports
try:
    airports_df = pd.read_csv('/content/canadian_airports.csv')
    CANADIAN_AIRPORTS = airports_df['code'].tolist()
except FileNotFoundError:
    print("Error: canadian_airports.csv not found. Please make sure the file is in the correct location.")
    CANADIAN_AIRPORTS = []
except KeyError:
    print("Error: 'code' column not found in the canadian_airports.csv file.")
    CANADIAN_AIRPORTS = []

# Generate all possible departure and arrival pairs
all_possible_pairs = set()
if CANADIAN_AIRPORTS:
  for dep in CANADIAN_AIRPORTS:
      for arr in CANADIAN_AIRPORTS:
          if dep != arr:
              all_possible_pairs.add(tuple([dep, arr]))

logged_pairs = set()
try:
    with open('/content/flights_found_dep_arr_log.csv', 'r') as file:
        reader = csv.reader(file)
        try:
            header = next(reader)
            if header != ['dep', 'arr', 'number_of_flights']:
                file.seek(0)
        except StopIteration:
            pass # File is empty

        for row in reader:
            if len(row) >= 2:
                logged_pairs.add(tuple(row[:2]))
except FileNotFoundError:
    print("Error: flights_found_dep_arr_log.csv not found. Cannot check combinations.")
    logged_pairs = set()


# Check if all possible combinations exist in the logged pairs
if all_possible_pairs and logged_pairs:
    if all_possible_pairs.issubset(logged_pairs):
        print("All possible combinations exist in the log.")
    else:
        print("Not all possible combinations exist in the log.")
        missing_pairs = all_possible_pairs - logged_pairs
        print("Missing pairs:", missing_pairs)
elif not CANADIAN_AIRPORTS:
    print("Could not generate possible pairs due to issues reading canadian_airports.csv")
elif not logged_pairs:
    print("No logged pairs found in flights_found_dep_arr_log.csv")
# Out:
# All possible combinations exist in the log.

# %%
# # UNUSED
# def find_all_canadian_flights():
#     all_flights = []
#     found_link = []
#     found_flights_df = pd.DataFrame(columns=['airport1', 'airport2'])

#     for origin_airport in CANADIAN_AIRPORTS:
#         for destination_airport in CANADIAN_AIRPORTS:

#             if [destination_airport, origin_airport] in found_link:
#               continue

#             if origin_airport != destination_airport:  # Don't check flights to the same airport
#                 print(f"Searching for flights from {origin_airport} to {destination_airport}...")
#                 flights = get_flights_between_airports(origin_airport, destination_airport)

#                 if flights:
#                     print(f"Found {len(flights)} flights from {origin_airport} to {destination_airport}.")
#                     all_flights.extend(flights)
#                     found_flights_df = pd.concat([found_flights_df, pd.DataFrame({'airport1': [origin_airport], 'airport2': [destination_airport]})], ignore_index=True)
#                     found_link.append([destination_airport, origin_airport]) # This line is not needed if not skipping reverse links
#                 else:
#                     print(f"No flights found from {origin_airport} to {destination_airport}.")

#                 # Sleep to respect API rate limits (essential for free tier)
#                 # This will take a very long time with the full list of airports.
#                 # Consider reducing the number of airports or increasing the sleep time if hitting rate limits.
#                 time.sleep(10)  # Adjust this based on the API's rate limits

#     found_flights_df.to_csv('connected_canadian_airports.csv', index=False)

#     return all_flights
